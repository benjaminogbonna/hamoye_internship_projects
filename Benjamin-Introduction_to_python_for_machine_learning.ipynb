# %% [markdown]
# # Introduction to Python for Machine Learning
#
# ## This notebook contains the code run to get the answers to the quiz

# %%
# notebook imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# import dataset

food_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
# print few rows (head and tail)

food_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# get dataset info

food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# get dataset description (min, max, mean, etc)

food_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
# get dataset shape

food_df.shape
# Out:
# (60943, 12)

# %%
year_and_area = food_df[['Y2017', 'Area']]
year_and_area.groupby(['Area']).first()
# Out:
#                                  Y2017
# Area
# Algeria                       41389.00
# Angola                        29817.00
# Benin                         11175.00
# Botswana                       2205.00
# Burkina Faso                  19193.00
# Cabo Verde                      537.00
# Cameroon                      24566.00
# Central African Republic       4596.00
# Chad                          15017.00
# Comoros                           0.00
# Congo                          5111.00
# Côte d'Ivoire                 24437.00
# Djibouti                        944.00
# Egypt                         96443.00
# Eswatini                       1125.00
# Ethiopia                     106400.00
# Ethiopia PDR                      0.00
# Gabon                          2065.00
# Gambia                         2214.00
# Ghana                         29121.00
# Guinea                        12068.00
# Guinea-Bissau                  1828.00
# Kenya                         50221.00
# ...

# %%
# get highes country in 2017

year_and_area.groupby(['Area']).first().max()
# Out:
# Y2017    190873.0
# dtype: float64

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
# get unique countries

len(food_df['Area'].unique())
# Out:
# 49

# %%
food_df.groupby('Element').first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
my_tuple = (1, 2, 5, 8)
my_tuple[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7902d4041b5f> in <module>
#       1 my_tuple = (1, 2, 5, 8)
# ----> 2 my_tuple[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
sns.pairplot(food_df)

# %% [markdown]
# ### Not trying to justify my score, but my PC freezed while running this last cell (the data seemed too big) and so I had to answer about 6 questions off the top of my head. I can't do them now, otherwise there would be descripancies in my answers and the notebook.
